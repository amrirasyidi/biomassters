# %%
# import libraries
import os
import rasterio
from tqdm import tqdm
import numpy as np
import tempfile
import matplotlib.pyplot as plt

from torch.utils.data import DataLoader, random_split
from torch import no_grad
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from torchgeo.datasets import NAIP, ChesapeakeDE, stack_samples, BioMassters
from torchgeo.datasets.utils import download_url
from torchgeo.samplers import RandomGeoSampler

# %%
from datasets import load_dataset

# %%
# select device, check if GPU available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
with rasterio.open('001b0634_S1_00.tif') as src:
    raster = src.read()
    plt.imshow(raster.transpose(1,2,0))
    # print(raster)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Load the dataset from Hugging Face
dataset = load_dataset("nascetti-a/BioMassters")
# Out:
# ...
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Load the dataset from Hugging Face
# ----> 2 dataset = load_dataset("nascetti-a/BioMassters")
#
# File ~/miniconda3/envs/torchgeo_env/lib/python3.9/site-packages/datasets/load.py:2587, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2582 verification_mode = VerificationMode(
#    2583     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2584 )
#    2586 # Create a dataset builder
# -> 2587 builder_instance = load_dataset_builder(
#    2588     path=path,
#    2589     name=name,
# ...

# %%
# Initialize the dataset
dataset = BioMassters(root='data', split='train', sensors=['S1', 'S2'])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Initialize the dataset
# ----> 2 dataset = BioMassters(root='data', split='train', sensors=['S1', 'S2'])
#
# File ~/miniconda3/envs/torchgeo_env/lib/python3.9/site-packages/torchgeo/datasets/biomassters.py:94, in BioMassters.__init__(self, root, split, sensors, as_time_series)
#      91 self.sensors = sensors
#      92 self.as_time_series = as_time_series
# ---> 94 self._verify()
#      96 # open metadata csv files
#      97 self.df = pd.read_csv(os.path.join(self.root, self.metadata_filename))
#
# File ~/miniconda3/envs/torchgeo_env/lib/python3.9/site-packages/torchgeo/datasets/biomassters.py:215, in BioMassters._verify(self)
#     212 if all(exists):
#     213     return
# --> 215 raise RuntimeError(f"Dataset not found in `root={self.root}`.")
#
# RuntimeError: Dataset not found in `root=data`.
